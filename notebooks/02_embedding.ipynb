# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/rag-chatbot-project/blob/main/notebooks/02_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-text-splitters langchain-openai langchain-community
import os
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document

# Set your OpenAI API key here or ensure it's set as an environment variable
os.environ["OPENAI_API_KEY"] = "YOUR_OPENAI_API_KEY" # Replace with your actual key

# Placeholder for documents - you should replace this with your actual document loading logic
documents = [Document(page_content="This is a sample document for testing the text splitter.")]

text_splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=20)

texts = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

vectorstore = FAISS.from_documents(texts, embeddings)

vectorstore.save_local("../vectorstore")
# Out:
# ...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_6115/451959319.py in <cell line: 0>()
#      18 embeddings = OpenAIEmbeddings()
#      19
# ---> 20 vectorstore = FAISS.from_documents(texts, embeddings)
#      21
#      22 vectorstore.save_local("../vectorstore")
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     812                 kwargs["ids"] = ids
#     813
# --> 814         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     815
#     816     @classmethod
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/vectorstores/faiss.py in from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#    1041                 faiss = FAISS.from_texts(texts, embeddings)
#    1042         """
# ...
