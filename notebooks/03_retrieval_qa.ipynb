# %% [markdown]
# <a href="https://colab.research.google.com/github/SIDDH4RTH245/rag-chatbot-project/blob/main/notebooks/03_retrieval_qa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain.chains import RetrievalQA

# Load embeddings
embeddings = OpenAIEmbeddings()

# Load vectorstore
vectorstore = FAISS.load_local(
    "../vectorstore",
    embeddings,
    allow_dangerous_deserialization=True
)

# Retriever
retriever = vectorstore.as_retriever()

# LLM
llm = ChatOpenAI()

# QA Chain
qa = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever
)

# Test
print(qa.run("What is AI?"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_21380/157932267.py in <cell line: 0>()
#       1 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#       2 from langchain_community.vectorstores import FAISS
# ----> 3 from langchain.chains import RetrievalQA
#       4
#       5 # Load embeddings
#
# ModuleNotFoundError: No module named 'langchain.chains'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
